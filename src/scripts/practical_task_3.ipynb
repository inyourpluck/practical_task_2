# %%
import pandas as pd
def extract_name(row):
    if row['Marriage_Status'] == 'Mrs' and '(' in row['Name']:
        return row['Name'].split(',')[1].split('.')[1].split('(')[1].split()[0]
    else:
        return row['Name'].split(',')[1].split('.')[1].split()[0]

from pyprojroot import here
df = pd.read_csv(here('src/data/train.csv'))

#Main info
df.info()

print(f'\nКоличество пропусков:\n{df.isna().sum()}')
print(f"\nСредние показатели:\n{df.select_dtypes(include=['number']).mean()}")
print(f"\nПроцент выживаемости у каждого класса пассажиров:\n{df.groupby('Pclass')['Survived'].sum() * 100/df.groupby('Pclass')['Survived'].count()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# Количество пропусков:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Средние показатели:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64
#
# Процент выживаемости у каждого класса пассажиров:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
#Most popular names
df['Marriage_Status'] = df['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()
df['First_Name'] = df.apply(extract_name, axis=1)

male_popular = df[df['Sex'] == 'male']['First_Name'].value_counts().head(1)
female_popular = df[df['Sex'] == 'female']['First_Name'].value_counts().head(1)

print(f'Самые популярные мужские имена:\n{male_popular}')
print(f'\nСамые популярные женские имена:\n{female_popular}')
# Out:
# Самые популярные мужские имена:
# First_Name
# William    35
# Name: count, dtype: int64
#
# Самые популярные женские имена:
# First_Name
# Anna    14
# Name: count, dtype: int64

# %%
#Most popular names by class
male_popular_by_class = df[df['Sex'] == 'male'].groupby('Pclass')['First_Name'].value_counts().groupby('Pclass').head(1)
female_popular_by_class = df[df['Sex'] == 'female'].groupby('Pclass')['First_Name'].value_counts().groupby('Pclass').head(1)

print(f'Самые популярные мужские имена по классу:\n{male_popular_by_class}')
print(f'\nСамые популярные женские имена по классу:\n{female_popular_by_class}')
# Out:
# Самые популярные мужские имена по классу:
# Pclass  First_Name
# 1       William       11
# 2       William        9
# 3       William       15
# Name: count, dtype: int64
#
# Самые популярные женские имена по классу:
# Pclass  First_Name
# 1       Elizabeth     5
# 2       Elizabeth     5
# 3       Anna          9
# Name: count, dtype: int64

# %%
#Passengers over 44 years of age
print(f"\nПассажиры, возраст которых больше 44 лет:\n{df[df['Age'] > 44]}")
# Out:
# Пассажиры, возраст которых больше 44 лет:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch      Ticket     Fare Cabin Embarked Marriage_Status First_Name
# 6        0       17463  51.8625   E46        S              Mr    Timothy
# 11       0      113783  26.5500  C103        S            Miss  Elizabeth
# 15       0      248706  16.0000   NaN        S             Mrs       Mary
# 33       0  C.A. 24579  10.5000   NaN        S              Mr     Edward
# 52       0    PC 17572  76.7292   D33        C             Mrs       Myna
# ..     ...         ...      ...   ...      ...             ...        ...
# 857      0      113055  26.5500   E17        S              Mr      Peter
# 862      0       17466  25.9292   D17        S             Mrs   Margaret
# 871      1       11751  52.5542   D35        S             Mrs     Sallie
# 873      0      345765   9.0000   NaN        S              Mr     Victor
# 879      1       11767  83.1583   C50        C             Mrs       Lily
#
# [115 rows x 14 columns]

# %%
#Passengers over 44 years of age and male
df_more_44_age = df[(df['Age'] > 44) & (df['Sex'] == 'male')]
print(f'\nПассажиры, возраст которых больше 44 лет и мужчины:\n{df_more_44_age}')
# Out:
# Пассажиры, возраст которых больше 44 лет и мужчины:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller  male
# ..           ...       ...     ...                             ...   ...
# 771          772         0       3         Jensen, Mr. Niels Peder  male
# 789          790         0       1        Guggenheim, Mr. Benjamin  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch       Ticket     Fare    Cabin Embarked  \
# 6    54.0      0      0        17463  51.8625      E46        S
# 33   66.0      0      0   C.A. 24579  10.5000      NaN        S
# 54   65.0      0      1       113509  61.9792      B30        C
# 62   45.0      1      0        36973  83.4750      C83        S
# 92   46.0      1      0  W.E.P. 5734  61.1750      E31        S
# ..    ...    ...    ...          ...      ...      ...      ...
# 771  48.0      0      0       350047   7.8542      NaN        S
# 789  46.0      0      0     PC 17593  79.2000  B82 B84        C
# 851  74.0      0      0       347060   7.7750      NaN        S
# 857  51.0      0      0       113055  26.5500      E17        S
# 873  47.0      0      0       345765   9.0000      NaN        S
#
#     Marriage_Status First_Name
# 6                Mr    Timothy
# 33               Mr     Edward
# 54               Mr  Engelhart
# 62               Mr      Henry
# 92               Mr    Herbert
# ..              ...        ...
# 771              Mr      Niels
# 789              Mr   Benjamin
# 851              Mr      Johan
# 857              Mr      Peter
# 873              Mr     Victor
#
# [79 rows x 14 columns]

# %%
#Number of n-seater cabins
df_cabin_value_counts = df['Cabin'].value_counts()
df_cabin_value_counts = df_cabin_value_counts[df_cabin_value_counts > 1]
print(f'\nКоличества n-местных кабин:\n{df_cabin_value_counts.value_counts()}')
# Out:
# Количества n-местных кабин:
# count
# 2    38
# 3     5
# 4     3
# Name: count, dtype: int64
